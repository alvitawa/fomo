"""

# Regular expression to extract the relevant parts
pattern = re.compile(
    r'\[(?P<acc_base>[0-9.]+)\], \[(?P<acc_novel>[0-9.]+)\], .*?CoPrompt_m(?P<momentum>[0-9.]+)_wstd(?P<wstd>[0-9.]+)_nctxt(?P<nctxt>\d+)_maxepoch\d+'
)

results = defaultdict(lambda: {"acc_base": [], "acc_novel": []})

for match in pattern.finditer(data):
    acc_base = float(match.group("acc_base"))
    acc_novel = float(match.group("acc_novel"))
    momentum = float(match.group("momentum"))
    wstd = float(match.group("wstd"))
    nctxt = int(match.group("nctxt"))
    
    key = (momentum, wstd, nctxt)
    results[key]["acc_base"].append(acc_base)
    results[key]["acc_novel"].append(acc_novel)

# Print results
for key, values in results.items():
    momentum, wstd, nctxt = key
    avg_acc_base = sum(values["acc_base"]) / len(values["acc_base"])
    avg_acc_novel = sum(values["acc_novel"]) / len(values["acc_novel"])
    print(f"Momentum: {momentum}, Wstd: {wstd}, Nctxt: {nctxt} -> "
          f"Average Accuracy Base: {avg_acc_base:.2f}, Average Accuracy Novel: {avg_acc_novel:.2f}")

# %%
import re
from collections import defaultdict

# Regular expression to match the accuracy and parameters
pattern = re.compile(
    r'\[(?P<acc_base>[0-9.]+)\], \[(?P<acc_novel>[0-9.]+)\], .*?CoPrompt_m(?P<momentum>[0-9.]+)_wstd(?P<wstd>[0-9.]+)_nctxt(?P<nctxt>\d+)_maxepoch\d+'
)

# Dictionary to hold the results
results = defaultdict(lambda: {"acc_base": [], "acc_novel": []})

# Example usage assuming 'data' is a list of strings, each representing a line in the data
for line in data:
    match = pattern.search(line)
    if match:
        acc_base = float(match.group("acc_base"))
        acc_novel = float(match.group("acc_novel"))
        momentum = float(match.group("momentum"))
        wstd = float(match.group("wstd"))
        nctxt = int(match.group("nctxt"))
        
        key = (momentum, wstd, nctxt)
        results[key]["acc_base"].append(acc_base)
        results[key]["acc_novel"].append(acc_novel)

# Print results
for key, values in results.items():
    momentum, wstd, nctxt = key
    avg_acc_base = sum(values["acc_base"]) / len(values["acc_base"])
    avg_acc_novel = sum(values["acc_novel"]) / len(values["acc_novel"])
    print(f"Momentum: {momentum}, Wstd: {wstd}, Nctxt: {nctxt} -> "
          f"Average Accuracy Base: {avg_acc_base:.2f}, Average Accuracy Novel: {avg_acc_novel:.2f}")

# %%
base, novel = None, None
std_base_dict = {}
std_novel_dict = {}
context_base_dict = {}
context_novel_dict = {}
momentum_base_dict = {}
momentum_novel_dict = {}


for i,data_point in enumerate(data.split("\n")):
    # print(data_point)
    if i % 2 ==0:
        if data_point == '':
            continue
        print(data_point.split('_'))
        _, momentum, std, context,_ = data_point.split('_')
        std = float(std.replace('wstd', ''))
        context = float(context.replace('nctxt', ''))
        momentum = float(momentum.replace('m', ''))
        if std not in std_base_dict:
            std_base_dict[std] = [base]
        else:
            std_base_dict[std].append(base)

        if std not in std_novel_dict:
            std_novel_dict[std] = [novel]
        else:
            std_novel_dict[std].append(novel)
        
        if context not in context_base_dict:
            context_base_dict[context] = [base]
        else:
            context_base_dict[context].append(base)
        
        if context not in context_novel_dict:
            context_novel_dict[context] = [novel]
        else:
            context_novel_dict[context].append(novel)
        
        if momentum not in momentum_base_dict:
            momentum_base_dict[momentum] = [base]
        else:
            momentum_base_dict[momentum].append(base)
        
        if momentum not in momentum_novel_dict:
            momentum_novel_dict[momentum] = [novel]
        else:
            momentum_novel_dict[momentum].append(novel)
        
        print(momentum, std, context)
    else:
        if data_point == '':
            continue
        else:
            base = float(data_point.split(",")[0].strip('[').strip(']'))
            novel = float(data_point.split(",")[1].replace(']', '').replace('[', ''))

            print(base, novel)
# Out:
# 75.64633178710938 78.0
# ['data/fomo/output/CoPrompt', 'm0.9', 'wstd0.012', 'nctxt1', 'maxepoch16']
# 0.9 0.012 1.0
# 77.86969757080078 75.2
# ['data/fomo/output/CoPrompt', 'm0.9', 'wstd0.001', 'nctxt3', 'maxepoch16']
# 0.9 0.001 3.0
# 76.68045806884766 75.9
# ['data/fomo/output/CoPrompt', 'm0.0', 'wstd0.012', 'nctxt3', 'maxepoch16']
# 0.0 0.012 3.0
# 76.9389877319336 74.7
# ['data/fomo/output/CoPrompt', 'm0.9', 'wstd0.012', 'nctxt3', 'maxepoch16']
# 0.9 0.012 3.0
# 76.78386688232422 74.6
# ['data/fomo/output/CoPrompt', 'm0.0', 'wstd0.001', 'nctxt2', 'maxepoch16']
# 0.0 0.001 2.0
# 76.05998229980469 75.3
# ['data/fomo/output/CoPrompt', 'm0.0', 'wstd0.001', 'nctxt3', 'maxepoch16']
# 0.0 0.001 3.0
# 72.85418701171875 77.9
# ['data/fomo/output/CoPrompt', 'm0.9', 'wstd0.08', 'nctxt2', 'maxepoch8']
# 0.9 0.08 2.0
# 74.0434341430664 76.7
# ['data/fomo/output/CoPrompt', 'm0.0', 'wstd0.012', 'nctxt2', 'maxepoch8']
# 0.0 0.012 2.0
# 75.43950653076172 75.3
# ...

# %%
for key in std_base_dict:
    print(key, sum(std_base_dict[key])/len(std_base_dict[key]), sum(std_novel_dict[key])/len(std_novel_dict[key]))
# Out:
# 0.012 73.73965883255005 74.44374999999998
# 0.001 74.90628242492676 74.39375000000001
# 0.08 73.7194081624349 73.87999999999998

# %%
for key in context_base_dict:
    print(key, sum(context_base_dict[key])/len(context_base_dict[key]), sum(context_novel_dict[key])/len(context_novel_dict[key]))
# Out:
# 1.0 73.79351997375488 74.54166666666666
# 3.0 74.52759343927556 74.68181818181819
# 2.0 74.24164136250813 74.61666666666667
# 4.0 73.99172655741374 73.18333333333332

# %%
for key in momentum_base_dict:
    print(key, sum(momentum_base_dict[key])/len(momentum_base_dict[key]), sum(momentum_novel_dict[key])/len(momentum_novel_dict[key]))
# Out:
# 0.9 74.21204110850458 74.29130434782608
# 0.0 74.05205154418945 74.20416666666667
